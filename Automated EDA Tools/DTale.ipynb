# %% [markdown]
# ### Another Amazing Library For EDA- Dtale

# %%
pip install dtale
# Out:
# Requirement already satisfied: dtale in c:\users\piyush.pathak\anaconda3\lib\site-packages (1.15.2)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: requests in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (2.24.0)
# Requirement already satisfied: statsmodels in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (0.11.1)
# Requirement already satisfied: lz4; python_version > "3.0" in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (3.1.0)
# Requirement already satisfied: dash>=1.5.0 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (1.16.2)
# Requirement already satisfied: Flask>=1.0 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (1.1.2)
# Requirement already satisfied: dash-daq in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (0.5.0)
# Requirement already satisfied: six in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (1.15.0)
# Requirement already satisfied: dash-bootstrap-components; python_version > "3.0" in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (0.10.6)
# Requirement already satisfied: pandas in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (1.0.5)
# Requirement already satisfied: scipy in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (1.5.0)
# Requirement already satisfied: Flask-Compress in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (1.5.0)
# Requirement already satisfied: dash-colorscales in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (0.0.4)
# Requirement already satisfied: flask-ngrok; python_version > "3.0" in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (0.0.25)
# Requirement already satisfied: squarify in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (0.4.3)
# Requirement already satisfied: scikit-learn>='0.21.0 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (0.23.1)
# Requirement already satisfied: future>=0.14.0 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (0.18.2)
# Requirement already satisfied: xarray in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (0.16.1)
# Requirement already satisfied: itsdangerous in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (1.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from requests->dtale) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from requests->dtale) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from requests->dtale) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from requests->dtale) (3.0.4)
# Requirement already satisfied: numpy>=1.14 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from statsmodels->dtale) (1.18.5)
# Requirement already satisfied: patsy>=0.5 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from statsmodels->dtale) (0.5.1)
# Requirement already satisfied: dash-table==4.10.1 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dash>=1.5.0->dtale) (4.10.1)
# Requirement already satisfied: dash-renderer==1.8.2 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dash>=1.5.0->dtale) (1.8.2)
# Requirement already satisfied: dash-html-components==1.1.1 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dash>=1.5.0->dtale) (1.1.1)
# Requirement already satisfied: dash-core-components==1.12.1 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dash>=1.5.0->dtale) (1.12.1)
# Requirement already satisfied: plotly in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dash>=1.5.0->dtale) (4.11.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from Flask>=1.0->dtale) (2.11.2)
# Requirement already satisfied: click>=5.1 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from Flask>=1.0->dtale) (7.1.2)
#
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from Flask>=1.0->dtale) (1.0.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from pandas->dtale) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from pandas->dtale) (2.8.1)
# Requirement already satisfied: brotli in c:\users\piyush.pathak\anaconda3\lib\site-packages (from Flask-Compress->dtale) (1.0.9)
# Requirement already satisfied: joblib>=0.11 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from scikit-learn>='0.21.0->dtale) (0.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from scikit-learn>='0.21.0->dtale) (2.1.0)
# Requirement already satisfied: setuptools>=38.4 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from xarray->dtale) (49.2.0.post20200714)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from plotly->dash>=1.5.0->dtale) (1.3.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0->dtale) (1.1.1)
# Collecting Dtale
#   Downloading dtale-1.15.2-py2.py3-none-any.whl (7.6 MB)
# Requirement already satisfied: future>=0.14.0 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from Dtale) (0.18.2)
# Collecting dash-daq
#   Downloading dash_daq-0.5.0.tar.gz (642 kB)
# Requirement already satisfied: requests in c:\users\piyush.pathak\anaconda3\lib\site-packages (from Dtale) (2.24.0)
# Collecting flask-ngrok; python_version > "3.0"
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Collecting xarray
#   Downloading xarray-0.16.1-py3-none-any.whl (720 kB)
# Requirement already satisfied: six in c:\users\piyush.pathak\anaconda3\lib\site-packages (from Dtale) (1.15.0)
# Collecting squarify
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Requirement already satisfied: statsmodels in c:\users\piyush.pathak\anaconda3\lib\site-packages (from Dtale) (0.11.1)
# Collecting Flask-Compress
#   Downloading Flask-Compress-1.5.0.tar.gz (6.5 kB)
# Collecting dash-colorscales
#   Downloading dash_colorscales-0.0.4.tar.gz (62 kB)
# Collecting dash>=1.5.0
#   Downloading dash-1.16.2.tar.gz (72 kB)
# Requirement already satisfied: pandas in c:\users\piyush.pathak\anaconda3\lib\site-packages (from Dtale) (1.0.5)
# Collecting dash-bootstrap-components; python_version > "3.0"
#   Downloading dash_bootstrap_components-0.10.6-py2.py3-none-any.whl (185 kB)
# Collecting lz4; python_version > "3.0"
#   Downloading lz4-3.1.0-cp38-cp38-win_amd64.whl (162 kB)
# Requirement already satisfied: scikit-learn>='0.21.0 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from Dtale) (0.23.1)
# Requirement already satisfied: itsdangerous in c:\users\piyush.pathak\anaconda3\lib\site-packages (from Dtale) (1.1.0)
# Requirement already satisfied: scipy in c:\users\piyush.pathak\anaconda3\lib\site-packages (from Dtale) (1.5.0)
# Requirement already satisfied: Flask>=1.0 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from Dtale) (1.1.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from requests->Dtale) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from requests->Dtale) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from requests->Dtale) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from requests->Dtale) (2.10)
# Requirement already satisfied: numpy>=1.15 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from xarray->Dtale) (1.18.5)
# Requirement already satisfied: setuptools>=38.4 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from xarray->Dtale) (49.2.0.post20200714)
# Requirement already satisfied: patsy>=0.5 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from statsmodels->Dtale) (0.5.1)
# Collecting brotli
#   Downloading Brotli-1.0.9-cp38-cp38-win_amd64.whl (365 kB)
# Collecting plotly
#   Downloading plotly-4.11.0-py2.py3-none-any.whl (13.1 MB)
# Collecting dash_renderer==1.8.2
#   Downloading dash_renderer-1.8.2.tar.gz (1.0 MB)
# Collecting dash-core-components==1.12.1
#   Downloading dash_core_components-1.12.1.tar.gz (3.4 MB)
# Collecting dash-html-components==1.1.1
#   Downloading dash_html_components-1.1.1.tar.gz (188 kB)
# Collecting dash-table==4.10.1
#   Downloading dash_table-4.10.1.tar.gz (1.8 MB)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from pandas->Dtale) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from pandas->Dtale) (2020.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from scikit-learn>='0.21.0->Dtale) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from scikit-learn>='0.21.0->Dtale) (0.16.0)
# Requirement already satisfied: click>=5.1 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from Flask>=1.0->Dtale) (7.1.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from Flask>=1.0->Dtale) (1.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from Flask>=1.0->Dtale) (2.11.2)
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0->Dtale) (1.1.1)
# Building wheels for collected packages: dash-daq, Flask-Compress, dash-colorscales, dash, dash-renderer, dash-core-components, dash-html-components, dash-table, retrying
#   Building wheel for dash-daq (setup.py): started
#   Building wheel for dash-daq (setup.py): finished with status 'done'
#   Created wheel for dash-daq: filename=dash_daq-0.5.0-py3-none-any.whl size=669707 sha256=d6d3f7acd7b4a55b170570f82d6c9aa9d540d0da1e7fb3196b74f24c8ada7365
#   Stored in directory: c:\users\piyush.pathak\appdata\local\pip\cache\wheels\00\35\e5\57e90f10c529601c6627400513cb65dd5adb09752411f5a050
#   Building wheel for Flask-Compress (setup.py): started
#   Building wheel for Flask-Compress (setup.py): finished with status 'done'
#   Created wheel for Flask-Compress: filename=Flask_Compress-1.5.0-py3-none-any.whl size=5277 sha256=9f919f0989cb811fb4b960080bad88666a2bfa5eb2d7a0432ed1a02552320dd8
#   Stored in directory: c:\users\piyush.pathak\appdata\local\pip\cache\wheels\39\3f\1a\07c215cf8b8f924cde78277257a31e254ef267ade7a99c909e
#   Building wheel for dash-colorscales (setup.py): started
#   Building wheel for dash-colorscales (setup.py): finished with status 'done'
#   Created wheel for dash-colorscales: filename=dash_colorscales-0.0.4-py3-none-any.whl size=62603 sha256=606aa51100c8adc83f2942b642215c92a1b0a70cf67b4742cbb2ee00f1be1d32
#   Stored in directory: c:\users\piyush.pathak\appdata\local\pip\cache\wheels\fe\33\33\172dbfe1efc739352828854a113df599a428b58f68ed0c4f75
#   Building wheel for dash (setup.py): started
#   Building wheel for dash (setup.py): finished with status 'done'
#   Created wheel for dash: filename=dash-1.16.2-py3-none-any.whl size=82325 sha256=51f5468223f07ab17223e8ff6a7f3413a9fe67e39aedd71681acc8486068fb1e
#   Stored in directory: c:\users\piyush.pathak\appdata\local\pip\cache\wheels\ad\ce\8c\f0a433a478be8773f043acc0587315d89b34dca6258c65786f
#   Building wheel for dash-renderer (setup.py): started
#   Building wheel for dash-renderer (setup.py): finished with status 'done'
#   Created wheel for dash-renderer: filename=dash_renderer-1.8.2-py3-none-any.whl size=1013932 sha256=811d72104159211e65ca27e808a7003433537245a56102ac354b7cf656bf784e
#   Stored in directory: c:\users\piyush.pathak\appdata\local\pip\cache\wheels\10\e3\34\d2d364809de513ac9112fe5143b038b4fe0d8eaca69702df30
#   Building wheel for dash-core-components (setup.py): started
#   Building wheel for dash-core-components (setup.py): finished with status 'done'
#   Created wheel for dash-core-components: filename=dash_core_components-1.12.1-py3-none-any.whl size=3475402 sha256=11beec887f19a5a6b714072b1b0c088f0f2f24df7ded66fc46d4c4997bb6f025
#   Stored in directory: c:\users\piyush.pathak\appdata\local\pip\cache\wheels\87\7c\e0\af30aa4769c1b5829fe41f0b9b1e1b5dce9899328c4619bc78
#   Building wheel for dash-html-components (setup.py): started
#   Building wheel for dash-html-components (setup.py): finished with status 'done'
#   Created wheel for dash-html-components: filename=dash_html_components-1.1.1-py3-none-any.whl size=427900 sha256=92994e21876cfb0aff42a0e1c02a8e199e788dd3de9d647da62eef66eb88d29d
#   Stored in directory: c:\users\piyush.pathak\appdata\local\pip\cache\wheels\ed\fc\1c\f68ef111763cc328876457a871024052e0b48950c63bc1ac04
#   Building wheel for dash-table (setup.py): started
#   Building wheel for dash-table (setup.py): finished with status 'done'
#   Created wheel for dash-table: filename=dash_table-4.10.1-py3-none-any.whl size=1825000 sha256=f8a9564877a6d4d047bbe2aa2712317944e209ed696d3ad55d9ed093993422cb
#   Stored in directory: c:\users\piyush.pathak\appdata\local\pip\cache\wheels\0c\5b\84\58c763a6dc2cc332fe404901748ad89d25d9dacd48778ee241
#   Building wheel for retrying (setup.py): started
#   Building wheel for retrying (setup.py): finished with status 'done'
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11435 sha256=7ec1fef01d97ce6a233a78b74bc934016250653e042d67b973869bfe6ccfe8c1
#   Stored in directory: c:\users\piyush.pathak\appdata\local\pip\cache\wheels\c4\a7\48\0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
# Successfully built dash-daq Flask-Compress dash-colorscales dash dash-renderer dash-core-components dash-html-components dash-table retrying
# Installing collected packages: brotli, Flask-Compress, retrying, plotly, dash-renderer, dash-core-components, dash-html-components, dash-table, dash, dash-daq, flask-ngrok, xarray, squarify, dash-colorscales, dash-bootstrap-components, lz4, Dtale
# Successfully installed Dtale-1.15.2 Flask-Compress-1.5.0 brotli-1.0.9 dash-1.16.2 dash-bootstrap-components-0.10.6 dash-colorscales-0.0.4 dash-core-components-1.12.1 dash-daq-0.5.0 dash-html-components-1.1.1 dash-renderer-1.8.2 dash-table-4.10.1 flask-ngrok-0.0.25 lz4-3.1.0 plotly-4.11.0 retrying-1.3.3 squarify-0.4.3 xarray-0.16.1

# %%
import seaborn as sns
# Out:
# Collecting dtale
#   Using cached dtale-1.15.2-py2.py3-none-any.whl (7.6 MB)
# Requirement already satisfied: future>=0.14.0 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (0.18.2)
# Collecting dash-bootstrap-components; python_version > "3.0"
#   Using cached dash_bootstrap_components-0.10.6-py2.py3-none-any.whl (185 kB)
# Processing c:\users\piyush.pathak\appdata\local\pip\cache\wheels\fe\33\33\172dbfe1efc739352828854a113df599a428b58f68ed0c4f75\dash_colorscales-0.0.4-py3-none-any.whl
# Collecting lz4; python_version > "3.0"
#   Using cached lz4-3.1.0-cp38-cp38-win_amd64.whl (162 kB)
# Requirement already satisfied: scikit-learn>='0.21.0 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (0.23.1)
# Requirement already satisfied: pandas in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (1.0.5)
# Processing c:\users\piyush.pathak\appdata\local\pip\cache\wheels\39\3f\1a\07c215cf8b8f924cde78277257a31e254ef267ade7a99c909e\flask_compress-1.5.0-py3-none-any.whl
# Requirement already satisfied: statsmodels in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (0.11.1)
# Requirement already satisfied: six in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (1.15.0)
# Collecting xarray
#   Using cached xarray-0.16.1-py3-none-any.whl (720 kB)
# Requirement already satisfied: requests in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (2.24.0)
# Collecting flask-ngrok; python_version > "3.0"
#   Using cached flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Requirement already satisfied: Flask>=1.0 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (1.1.2)
# Collecting squarify
#   Using cached squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Processing c:\users\piyush.pathak\appdata\local\pip\cache\wheels\00\35\e5\57e90f10c529601c6627400513cb65dd5adb09752411f5a050\dash_daq-0.5.0-py3-none-any.whl
# Processing c:\users\piyush.pathak\appdata\local\pip\cache\wheels\ad\ce\8c\f0a433a478be8773f043acc0587315d89b34dca6258c65786f\dash-1.16.2-py3-none-any.whl
# Requirement already satisfied: scipy in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (1.5.0)
# Requirement already satisfied: itsdangerous in c:\users\piyush.pathak\anaconda3\lib\site-packages (from dtale) (1.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from scikit-learn>='0.21.0->dtale) (0.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from scikit-learn>='0.21.0->dtale) (2.1.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from scikit-learn>='0.21.0->dtale) (1.18.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from pandas->dtale) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from pandas->dtale) (2020.1)
# Requirement already satisfied: brotli in c:\users\piyush.pathak\anaconda3\lib\site-packages (from Flask-Compress->dtale) (1.0.9)
# Requirement already satisfied: patsy>=0.5 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from statsmodels->dtale) (0.5.1)
# Requirement already satisfied: setuptools>=38.4 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from xarray->dtale) (49.2.0.post20200714)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from requests->dtale) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from requests->dtale) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from requests->dtale) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from requests->dtale) (3.0.4)
# Requirement already satisfied: click>=5.1 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from Flask>=1.0->dtale) (7.1.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from Flask>=1.0->dtale) (1.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from Flask>=1.0->dtale) (2.11.2)
# Collecting plotly
#   Using cached plotly-4.11.0-py2.py3-none-any.whl (13.1 MB)
# Processing c:\users\piyush.pathak\appdata\local\pip\cache\wheels\87\7c\e0\af30aa4769c1b5829fe41f0b9b1e1b5dce9899328c4619bc78\dash_core_components-1.12.1-py3-none-any.whl
# Processing c:\users\piyush.pathak\appdata\local\pip\cache\wheels\0c\5b\84\58c763a6dc2cc332fe404901748ad89d25d9dacd48778ee241\dash_table-4.10.1-py3-none-any.whl
# Processing c:\users\piyush.pathak\appdata\local\pip\cache\wheels\ed\fc\1c\f68ef111763cc328876457a871024052e0b48950c63bc1ac04\dash_html_components-1.1.1-py3-none-any.whl
# Processing c:\users\piyush.pathak\appdata\local\pip\cache\wheels\10\e3\34\d2d364809de513ac9112fe5143b038b4fe0d8eaca69702df30\dash_renderer-1.8.2-py3-none-any.whl
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0->dtale) (1.1.1)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\piyush.pathak\anaconda3\lib\site-packages (from plotly->dash>=1.5.0->dtale) (1.3.3)
# Installing collected packages: plotly, dash-core-components, dash-table, dash-html-components, Flask-Compress, dash-renderer, dash, dash-bootstrap-components, dash-colorscales, lz4, xarray, flask-ngrok, squarify, dash-daq, dtale
# ERROR: plotly 4.11.0 requires retrying>=1.3.3, which is not installed.
# ERROR: flask-compress 1.5.0 requires brotli, which is not installed.
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'C:\\Users\\piyush.pathak\\Anaconda3\\Lib\\site-packages\\lz4\\_version.cp38-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
df=sns.load_dataset('planets')

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.describe()
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000

# %%
import dtale

# %%
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PIPA-BLR-01:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'

import numpy as np
import pandas as pd

if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

chart = np.histogram(df[~pd.isnull(df['distance'])][['distance']], bins=20)
# main statistics
stats = df['distance'].describe().to_frame().T

# %%
stats
# Out:
#           count        mean         std   min    25%    50%    75%     max
# distance  808.0  264.069282  733.116493  1.35  32.56  55.25  178.5  8500.0

# %%
df.corr()
# Out:
#                   number  orbital_period      mass  distance      year
# number          1.000000       -0.012570 -0.241429 -0.033638  0.147849
# orbital_period -0.012570        1.000000  0.173725 -0.034365 -0.032333
# mass           -0.241429        0.173725  1.000000  0.274082 -0.123787
# distance       -0.033638       -0.034365  0.274082  1.000000  0.178922
# year            0.147849       -0.032333 -0.123787  0.178922  1.000000
# {'metas': '<meta http-equiv="X-UA-Compatible" content="IE=edge">\n      <meta charset="UTF-8">', 'title': 'Dash', 'css': '<link rel="stylesheet" href="/css/main.css">\n<link rel="stylesheet" href="/css/dash.css">\n<link rel="stylesheet" href="/css/github_fork.css">', 'config': '<script id="_dash-config" type="application/json">{"url_base_pathname": null, "requests_pathname_prefix": "/charts/", "ui": false, "props_check": false, "show_undo_redo": false, "suppress_callback_exceptions": true, "update_title": "Updating..."}</script>', 'scripts': '<script src="/charts/_dash-component-suites/dash_renderer/polyfill@7.v1_8_2m1601456825.8.7.min.js"></script>\n<script src="/charts/_dash-component-suites/dash_renderer/react@16.v1_8_2m1601456825.13.0.min.js"></script>\n<script src="/charts/_dash-component-suites/dash_renderer/react-dom@16.v1_8_2m1601456825.13.0.min.js"></script>\n<script src="/charts/_dash-component-suites/dash_renderer/prop-types@15.v1_8_2m1601456825.7.2.min.js"></script>\n<script src="/dash/components_bundle.js"></script>\n<script src="/dash/custom_bundle.js"></script>\n<script src="/dist/base_styles_bundle.js"></script>\n<script src="/charts/_dash-component-suites/dash_html_components/dash_html_components.v1_1_1m1601456826.min.js"></script>\n<script src="/charts/_dash-component-suites/dash_core_components/async-datepicker.v1_12_1m1601456826.js"></script>\n<script src="/charts/_dash-component-suites/dash_core_components/async-dropdown.v1_12_1m1601456826.js"></script>\n<script src="/charts/_dash-component-suites/dash_core_components/async-graph.v1_12_1m1601456826.js"></script>\n<script src="/charts/_dash-component-suites/dash_core_components/async-highlight.v1_12_1m1601456826.js"></script>\n<script src="/charts/_dash-component-suites/dash_core_components/async-markdown.v1_12_1m1601456826.js"></script>\n<script src="/charts/_dash-component-suites/dash_core_components/async-slider.v1_12_1m1601456826.js"></script>\n<script src="/charts/_dash-component-suites/dash_core_components/async-upload.v1_12_1m1601456826.js"></script>\n<script src="/charts/_dash-component-suites/dash_core_components/dash_core_components.v1_12_1m1601456826.min.js"></script>\n<script src="/charts/_dash-component-suites/dash_core_components/dash_core_components-shared.v1_12_1m1601456826.js"></script>\n<script src="/charts/_dash-component-suites/dash_core_components/plotly.v1_12_1m1601456826.min.js"></script>\n<script src="/charts/_dash-component-suites/dash_bootstrap_components/_components/dash_bootstrap_components.v0_10_6m1601456830.min.js"></script>\n<script src="/charts/_dash-component-suites/dash_daq/async-colorpicker.v0_5_0m1601456830.js"></script>\n<script src="/charts/_dash-component-suites/dash_daq/async-slider.v0_5_0m1601456830.js"></script>\n<script src="/charts/_dash-component-suites/dash_daq/dash_daq.v0_5_0m1601456830.min.js"></script>\n<script src="/charts/_dash-component-suites/dash_colorscales/bundle.v0_0_4m1601456831.js"></script>\n<script src="/charts/_dash-component-suites/dash_renderer/dash_renderer.v1_8_2m1601456825.min.js"></script>', 'app_entry': '\n<div id="react-entry-point">\n    <div class="_dash-loading">\n        Loading...\n    </div>\n</div>\n', 'favicon': '<link rel="icon" type="image/x-icon" href="/charts/_favicon.ico?v=1.16.2">', 'renderer': '<script id="_dash-renderer" type="application/javascript">var renderer = new DashRenderer();</script>'}

# %%
s = df['distance']
q1 = s.quantile(0.25)
q3 = s.quantile(0.75)
iqr = q3 - q1
iqr_lower = q1 - 1.5 * iqr
iqr_upper = q3 + 1.5 * iqr
outliers = dict(s[(s < iqr_lower) | (s > iqr_upper)])

# %%
outliers
# Out:
# {39: 500.0,
#  40: 500.0,
#  93: 680.0,
#  100: 460.0,
#  102: 560.0,
#  103: 1150.0,
#  104: 1060.0,
#  105: 1340.0,
#  106: 840.0,
#  107: 920.0,
#  108: 870.0,
#  109: 770.0,
#  110: 1230.0,
#  111: 600.0,
#  158: 480.0,
#  185: 535.0,
#  187: 411.0,
#  189: 642.0,
#  190: 501.0,
#  192: 447.0,
#  193: 542.0,
#  197: 453.0,
#  654: 550.0,
#  658: 1330.0,
#  659: 650.0,
#  660: 650.0,
#  661: 650.0,
#  664: 613.0,
#  665: 613.0,
#  666: 613.0,
#  667: 613.0,
#  668: 613.0,
#  669: 613.0,
#  670: 600.0,
#  672: 980.0,
#  675: 800.0,
#  679: 2119.0,
#  680: 2119.0,
#  688: 800.0,
#  689: 800.0,
#  690: 1200.0,
#  691: 1200.0,
#  701: 1400.0,
#  702: 1400.0,
#  703: 1400.0,
#  704: 1400.0,
#  705: 1400.0,
#  706: 2100.0,
#  707: 2100.0,
#  718: 1499.0,
#  719: 1645.0,
#  720: 470.0,
#  721: 470.0,
#  725: 600.0,
#  726: 1200.0,
#  727: 2700.0,
#  728: 770.0,
#  732: 1950.0,
#  733: 2250.0,
#  735: 855.0,
#  736: 855.0,
#  737: 1500.0,
#  738: 1500.0,
#  776: 1000.0,
#  780: 1107.0,
#  781: 1107.0,
#  787: 1180.0,
#  788: 1180.0,
#  789: 800.0,
#  790: 1330.0,
#  791: 1140.0,
#  793: 570.0,
#  818: 780.0,
#  819: 780.0,
#  820: 780.0,
#  821: 780.0,
#  822: 780.0,
#  823: 780.0,
#  824: 780.0,
#  825: 1030.0,
#  898: 1056.0,
#  901: 2000.0,
#  905: 3600.0,
#  909: 2300.0,
#  910: 2800.0,
#  911: 7720.0,
#  912: 7560.0,
#  924: 2570.0,
#  925: 4080.0,
#  926: 4080.0,
#  927: 1760.0,
#  928: 4970.0,
#  933: 600.0,
#  934: 2500.0,
#  938: 1200.0,
#  945: 1200.0,
#  951: 8500.0,
#  952: 8500.0,
#  955: 492.0,
#  959: 408.0,
#  974: 400.0,
#  990: 450.0,
#  1008: 455.0,
#  1011: 400.0,
#  1012: 480.0,
#  1023: 550.0,
#  1026: 470.0,
#  1028: 3200.0}
